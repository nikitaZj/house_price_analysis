# %%
def getUserAgent():
    UA_list = [
        "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36",
        "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) App leWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53",
        "Mozilla/5.0 (Windows; U; Windows NT 5.2) AppleWebKit/525.13 (KHTML, like Gecko) Chrome/0.2.149.27 Safari/525.13",
        "Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1) ;  QIHU 360EE)",
        "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Trident/4.0; Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1) ; Maxthon/3.0)",
        "Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_8; en-us) AppleWebKit/534.50 (KHTML, like Gecko) Version/5.1 Safari/534.50",
        "Mozilla/5.0 (Macintosh; U; IntelMac OS X 10_6_8; en-us) AppleWebKit/534.50 (KHTML, like Gecko) Version/5.1Safari/534.50",
        "Mozilla/5.0 (Windows NT 10.0; WOW64; rv:51.0) Gecko/20100101 Firefox/51.0",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1",
        "Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1092.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/19.77.34.5 Safari/537.1",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.9 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko) Chrome/19.0.1084.36 Safari/536.5",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1063.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1062.0 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.1 Safari/536.3",
        "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko) Chrome/19.0.1061.0 Safari/536.3",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24",
        "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24"]
    return random.choice(UA_list)

# %%
# 时间：2022/1/1 21:57
import requests
from lxml import etree
import time
import csv
import pickle
class Lianjiaspider(object):
    def __init__(self):
#         self.url='https://sh.lianjia.com/ershoufang/pg{}/'
        self.url = 'https://sh.fang.lianjia.com/loupan/pg{}/'
#         self.henders={'User-Agent'a: 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36'}
        self.df = pd.DataFrame(columns = [['house_name', 'total_price', 'unit_price', 'unit_price_desc']])
        
    def get_page(self,url):
        time.sleep(3)
        self.henders={'User-Agent':getUserAgent()}
        respones=requests.get(url=url,headers=self.henders)
        respones.encoding='utf-8'
        html=respones.text
        return self.parse_page(html)
        
    def parse_page(self,html):
        paser_html=etree.HTML(html)
        parse_page_result = {}
        li_list = paser_html.xpath('//ul[@class="resblock-list-wrapper"]/li[@class="resblock-list post_ulog_exposure_scroll has-results"]|//ul[@class="resblock-list-wrapper"]/li[@class="resblock-list post_ulog_exposure_scroll"]')
        
        print(li_list)
        for i in range(len(li_list)):
            li = li_list[i]
            house_dict = {}
            # 名称
            house_dict['house_name'] = li.xpath('.//div/div[1]/a/text()')#.strip()
            # 总价
            house_dict['total_price']=li.xpath('.//div[@class="second"]/text()')#[0].strip()
            # 单价
            house_dict['unit_price']=li.xpath('.//div[@class="main-price"]/span[@class="number"]/text()')#[0].strip()
            house_dict['unit_price_desc']=li.xpath('.//div[@class="main-price"]/span[@class="desc"]/text()')#[0].strip()
            # 房屋类型
            house_dict['type']=li.xpath('.//div[@class="resblock-name"]/span[1]/text()')
            # 房屋所在区
            house_dict['location1']=li.xpath('.//div[@class="resblock-location"]/span[1]/text()')
            # 房屋面积
            house_dict['area']=li.xpath('.//div[@class="resblock-area"]/span[1]/text()')
            print(house_dict)
            parse_page_result[i] = house_dict
        return parse_page_result
            
    def main(self):
        self.main_result = {}
        for pg in range(88,91):
            print('page:',pg)
            url=self.url.format(pg)
            self.main_result['pg'+str(pg)] = self.get_page(url)

if __name__ == "__main__":
    start=time.time()
    lianjia=Lianjiaspider()
    lianjia.main()
    end=time.time()
    print('执行时间为：%0.2f'%(end - start))
# Out:
# page: 88
# [<Element li at 0x2349db1a508>, <Element li at 0x2349ba74608>, <Element li at 0x234a7d4a788>, <Element li at 0x2349a6f0988>, <Element li at 0x2349b80a208>, <Element li at 0x2349b80ae08>, <Element li at 0x2349b80a848>, <Element li at 0x2349b80af08>, <Element li at 0x2349b80ad08>, <Element li at 0x2349b80ad88>, <Element li at 0x2349b80a608>, <Element li at 0x2349b80adc8>, <Element li at 0x2349b80a908>, <Element li at 0x2349b80a808>, <Element li at 0x2349b80acc8>, <Element li at 0x2349b80abc8>, <Element li at 0x2349a776dc8>, <Element li at 0x2349a776608>, <Element li at 0x2349a776688>, <Element li at 0x2349a776ac8>]
# {'house_name': ['金科旭辉悦章'], 'total_price': ['总价260(万/套)'], 'unit_price': ['21500'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 105-142㎡']}
# {'house_name': ['中骏璟尚'], 'total_price': ['总价365(万/套)'], 'unit_price': ['37000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['嘉定'], 'area': ['建面 76-115㎡']}
# {'house_name': ['龙光玖云华庭'], 'total_price': ['总价120(万/套)'], 'unit_price': ['16500'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 73-105㎡']}
# {'house_name': ['中骏御景台'], 'total_price': ['总价596(万/套)'], 'unit_price': ['43000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['别墅'], 'location1': ['青浦'], 'area': ['建面 151㎡']}
# {'house_name': ['金融家'], 'total_price': ['总价992(万/套)'], 'unit_price': ['49000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['别墅'], 'location1': ['浦东'], 'area': ['建面 195-208㎡']}
# {'house_name': ['正荣·悦珑府'], 'total_price': ['总价290(万/套)'], 'unit_price': ['36500'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['嘉定'], 'area': ['建面 75-89㎡']}
# {'house_name': ['融侨星誉'], 'total_price': ['总价320(万/套)'], 'unit_price': ['36500'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['嘉定'], 'area': ['建面 81-97㎡']}
# {'house_name': ['金成·滨湖上境'], 'total_price': ['总价121(万/套)'], 'unit_price': ['13500'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 89-117㎡']}
# {'house_name': ['保利明玥湖光'], 'total_price': ['总价510(万/套)'], 'unit_price': ['40000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['奉贤'], 'area': ['建面 96-143㎡']}
# {'house_name': ['融创杭州湾壹号'], 'total_price': ['总价169(万/套)'], 'unit_price': ['14500'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 117㎡']}
# {'house_name': ['海月四季'], 'total_price': ['总价320(万/套)'], 'unit_price': ['37000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['奉贤'], 'area': ['建面 72-95㎡']}
# {'house_name': ['海月四季'], 'total_price': ['总价660(万/套)'], 'unit_price': ['47000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['别墅'], 'location1': ['奉贤'], 'area': ['建面 120-140㎡']}
# {'house_name': ['明月辰光'], 'total_price': ['总价125(万/套)'], 'unit_price': ['16500'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 75-95㎡']}
# {'house_name': ['虹桥悦澜'], 'total_price': ['总价650(万/套)'], 'unit_price': ['61300'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['青浦'], 'area': ['建面 99-135㎡']}
# {'house_name': ['建发云锦湾'], 'total_price': ['总价410(万/套)'], 'unit_price': ['44800'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['宝山'], 'area': ['建面 88-98㎡']}
# {'house_name': ['建发浦上湾'], 'total_price': ['总价435(万/套)'], 'unit_price': ['40400'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['闵行'], 'area': ['建面 88-128㎡']}
# {'house_name': ['圣宇豪庭'], 'total_price': ['总价862(万/套)'], 'unit_price': ['68000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['浦东'], 'area': ['建面 137-308㎡']}
# {'house_name': ['弘阳 ·昕悦棠'], 'total_price': ['总价93(万/套)'], 'unit_price': ['10500'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 89-118㎡']}
# {'house_name': ['古北中央公园'], 'total_price': ['总价1110(万/套)'], 'unit_price': ['108800'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['闵行'], 'area': ['建面 123-168㎡']}
# {'house_name': ['恒盛豪庭阳光里'], 'total_price': ['总价600(万/套)'], 'unit_price': ['45000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['商业'], 'location1': ['宝山'], 'area': []}
# page: 89
# [<Element li at 0x2349b80a088>, <Element li at 0x2349b7e4408>, <Element li at 0x2349b7e41c8>, <Element li at 0x2349a6f0988>, <Element li at 0x2349ba74608>, <Element li at 0x2349a6ed288>, <Element li at 0x2349b7eef88>, <Element li at 0x2349b7ee308>, <Element li at 0x2349b7ee3c8>, <Element li at 0x234a7d4a788>, <Element li at 0x2349b7eec88>, <Element li at 0x2349b7ee508>, <Element li at 0x2349b7ee688>, <Element li at 0x2349b7d7588>, <Element li at 0x2349b7d7208>, <Element li at 0x2349b7d7048>, <Element li at 0x2349b7d71c8>, <Element li at 0x2349b7d7948>, <Element li at 0x2349b7d7288>, <Element li at 0x2349b7d7408>]
# {'house_name': ['融信旭辉世纪古美'], 'total_price': ['总价975(万/套)'], 'unit_price': ['82500'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['闵行'], 'area': ['建面 89-149㎡']}
# {'house_name': ['德信交投·隐秀云庐'], 'total_price': ['总价400(万/套)'], 'unit_price': ['45028'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['闵行'], 'area': ['建面 90㎡']}
# {'house_name': ['建发云锦湾'], 'total_price': ['总价730(万/套)'], 'unit_price': ['54000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['别墅'], 'location1': ['宝山'], 'area': ['建面 132-142㎡']}
# {'house_name': ['鸿翔天宸府'], 'total_price': ['总价150(万/套)'], 'unit_price': ['18000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 70-95㎡']}
# {'house_name': ['中建壹府澜庭'], 'total_price': ['总价550(万/套)'], 'unit_price': ['63000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['浦东'], 'area': ['建面 87-115㎡']}
# {'house_name': ['中建壹府澜庭'], 'total_price': ['总价855(万/套)'], 'unit_price': ['72000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['别墅'], 'location1': ['浦东'], 'area': ['建面 121-133㎡']}
# {'house_name': ['德信交投·隐秀云庐'], 'total_price': ['总价685(万/套)'], 'unit_price': ['53440'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['别墅'], 'location1': ['闵行'], 'area': ['建面 120-130㎡']}
# {'house_name': ['同建大诚首府'], 'total_price': ['总价180(万/套)'], 'unit_price': ['14000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': []}
# {'house_name': ['同建大诚首府'], 'total_price': ['总价270(万/套)'], 'unit_price': ['19500'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['别墅'], 'location1': ['上海周边'], 'area': []}
# {'house_name': ['新华御府'], 'total_price': ['总价400(万/套)'], 'unit_price': ['28000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['别墅'], 'location1': ['金山'], 'area': ['建面 118-144㎡']}
# {'house_name': ['滴水湖馨苑'], 'total_price': ['总价517(万/套)'], 'unit_price': ['32000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['别墅'], 'location1': ['浦东'], 'area': ['建面 135-148㎡']}
# {'house_name': ['翡翠风华城'], 'total_price': ['总价195(万/套)'], 'unit_price': ['20000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 92-124㎡']}
# {'house_name': ['佳源印象里'], 'total_price': ['总价130(万/套)'], 'unit_price': ['14000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 72-120㎡']}
# {'house_name': ['大华锦绣悦府'], 'total_price': ['总价428(万/套)'], 'unit_price': ['52000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['宝山'], 'area': ['建面 80-97㎡']}
# {'house_name': ['上湾璟园'], 'total_price': ['总价240(万/套)'], 'unit_price': ['22800'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 105-142㎡']}
# {'house_name': ['新希望锦麟府'], 'total_price': ['总价225(万/套)'], 'unit_price': ['19000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 107-142㎡']}
# {'house_name': ['清韵雅苑'], 'total_price': ['总价280(万/套)'], 'unit_price': ['31974'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['浦东'], 'area': ['建面 63-141㎡']}
# {'house_name': ['嘉裕富士花园'], 'total_price': [], 'unit_price': ['价格待定'], 'unit_price_desc': [], 'type': ['商业'], 'location1': ['上海周边'], 'area': []}
# {'house_name': ['山水壹号'], 'total_price': [], 'unit_price': ['17500'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 92㎡']}
# {'house_name': ['春风里'], 'total_price': ['总价110(万/套)'], 'unit_price': ['14000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 57-130㎡']}
# page: 90
# [<Element li at 0x2349a68b348>, <Element li at 0x2349a68b408>, <Element li at 0x2349a68b3c8>, <Element li at 0x2349a776688>, <Element li at 0x2349a776dc8>, <Element li at 0x2349db1a288>, <Element li at 0x2349db1a508>, <Element li at 0x2349b7d7408>, <Element li at 0x2349a66b108>, <Element li at 0x2349daf3c08>, <Element li at 0x2349a66bb08>, <Element li at 0x2349a66b4c8>, <Element li at 0x2349a66b488>, <Element li at 0x2349a66b208>, <Element li at 0x2349a66b248>, <Element li at 0x2349a66b408>]
# {'house_name': ['伊顿公馆'], 'total_price': [], 'unit_price': ['32000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['商业'], 'location1': ['浦东'], 'area': []}
# {'house_name': ['碧桂园湖悦天境花园'], 'total_price': ['总价350(万/套)'], 'unit_price': ['25000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['别墅'], 'location1': ['上海周边'], 'area': ['建面 115-150㎡']}
# {'house_name': ['五洲翡丽湾'], 'total_price': [], 'unit_price': ['8700'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 136-149㎡']}
# {'house_name': ['嘉禾金茂府'], 'total_price': ['总价175(万/套)'], 'unit_price': ['15400'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 103-136㎡']}
# {'house_name': ['旭辉光耀城'], 'total_price': ['总价165(万/套)'], 'unit_price': ['17000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 65-109㎡']}
# {'house_name': ['普禧观澜'], 'total_price': [], 'unit_price': ['价格待定'], 'unit_price_desc': [], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 126-136㎡']}
# {'house_name': ['普禧观澜'], 'total_price': ['总价250(万/套)'], 'unit_price': ['30000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['商业'], 'location1': ['上海周边'], 'area': []}
# {'house_name': ['中南锦庭'], 'total_price': [], 'unit_price': ['价格待定'], 'unit_price_desc': [], 'type': ['商业'], 'location1': ['奉贤'], 'area': []}
# {'house_name': ['天和珺府'], 'total_price': ['总价150(万/套)'], 'unit_price': ['9200'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 147-159㎡']}
# {'house_name': ['华晖绿苑'], 'total_price': [], 'unit_price': ['价格待定'], 'unit_price_desc': [], 'type': ['住宅'], 'location1': ['杨浦'], 'area': ['建面 197㎡']}
# {'house_name': ['棕榈湾花园(昆山)'], 'total_price': ['总价205(万/套)'], 'unit_price': ['23000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 94-115㎡']}
# {'house_name': ['合生国际名都'], 'total_price': ['总价100(万/套)'], 'unit_price': ['11000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 82-95㎡']}
# {'house_name': ['公元2040'], 'total_price': ['总价410(万/套)'], 'unit_price': ['45481'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['浦东'], 'area': ['建面 85-117㎡']}
# {'house_name': ['卡森卫星城'], 'total_price': ['总价615(万/套)'], 'unit_price': ['20000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['别墅'], 'location1': ['上海周边'], 'area': ['建面 300㎡']}
# {'house_name': ['魏武宸章'], 'total_price': ['总价150(万/套)'], 'unit_price': ['13500'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['上海周边'], 'area': ['建面 89-115㎡']}
# {'house_name': ['山屿海幸福城'], 'total_price': [], 'unit_price': ['11000'], 'unit_price_desc': ['\xa0元/㎡(均价)'], 'type': ['住宅'], 'location1': ['安吉县'], 'area': ['建面 58-68㎡']}
# 执行时间为：12.84

# %%
# 暂时存一下爬取结果：爬到85页时，要求进行验证，所以手动进行验证后，重新从85页开始爬取
# result_1_7 = lianjia.main_result
# result_8_61 = lianjia.main_result
# result_85_90 = lianjia.main_result

# %%
shanghai_new = result_1_7.copy()
shanghai_new.update(result_8_61)
shanghai_new.update(result_85_90)
# 保存
def pkl_save(filename, file):
    #将file保存到filename中
    output = open(filename, 'wb')
    pickle.dump(file, output)
    output.close()
    
filename = './shanghai_new.pkl' # 文件名
file = shanghai_new # 文件
pkl_save(filename, file)
